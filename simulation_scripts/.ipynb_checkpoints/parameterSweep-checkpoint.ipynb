# %%
import util
from plotCommunity import plotCommunity
from community import community
import numpy as np
# from simulateWithoutAgent import simulate
from controlSimulation import simulate
# from simulateRL import simulate
import matplotlib.pyplot as plt
import copy, pickle, mdp

# %%
parameterRange = [0.3]
c = community(300,4,10)
data = []
distanceMatrices = []

for r in parameterRange:
#     c = copy.deepcopy(c_original)
    c.allRadii = (np.random.normal(r,0.1,c.numberMembers)**2 + np.random.normal(r,0.1, c.numberMembers)**2)**0.5
#     c.allGregariousness = np.random.normal(r,0.1,c.numberMembers)
#     c.allThresholds = np.random.normal(0.2, 0.1, c.numberMembers)
#     data = simulate(c, T=100)
#     distanceMatrices.append(c.distanceMatrix)
    
    agentMDP = mdp.agentMDP(community = c, index=0, sampleSize=10)
    agentMDP.T = 100
    agentMDP.tau = 10
    rl = mdp.QLearningAlgorithm(agentMDP.index, agentMDP.tau, agentMDP.c, agentMDP.actions, agentMDP.discount(), mdp.communityFeatureExtractor, explorationProb = 0.2)            
    data = simulate(rl, numTrials=1, maxIterations=100)
    distanceMatrices.append(rl.c.distanceMatrix)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-3061099f0506> in <module>
#      16     agentMDP.tau = 10
#      17     rl = mdp.QLearningAlgorithm(agentMDP.index, agentMDP.tau, agentMDP.c, agentMDP.actions, agentMDP.discount(), mdp.communityFeatureExtractor, explorationProb = 0.2)
# ---> 18     data = simulate(rl, numTrials=1, maxIterations=100)
#      19     distanceMatrices.append(rl.c.distanceMatrix)
#
# ~/project/controlSimulation.py in simulate(rl, numTrials, maxIterations, verbose, sort)
#      59
#      60             for n in range(agentMDP.tau):
# ---> 61                 Transfer.probabilisticMerge()
#      62             newState = agentMDP.observeCommunity()
#      63
#
# ~/project/transfer.py in probabilisticMerge(self)
#      50     # Probabilistically merge everyone's ideas with a subset of the community each time step.
# ...

# %%
for i in range(len(parameterRange)):
    plt.hist(distanceMatrices[i].flatten(),500)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-df49e418228a> in <module>
#       1 for i in range(len(parameterRange)):
# ----> 2     plt.hist(distanceMatrices[i].flatten(),500)
#       3     plt.show()
#
# IndexError: list index out of range

# %%
plotCommunity(c, data[0:6], fps=4)

# %%
plt.scatter(data[3][-1],data[4][-1],s=1000*c.allRadii**2,alpha=0.08)
plt.show()

# %%
from scipy import cluster
centroids, loss = cluster.vq.kmeans(c.allPositions,1)
centroids
# Out:
# array([[-0.04231642, -0.00166471]])

# %%
def closest_centroids(points,centroids):
    distances = np.sqrt(((points - centroids[:,np.newaxis])**2).sum(axis=2))
    return np.argmin(distances,axis=0)

# %%
c.ideaDistribution[closest_centroids(c.allPositions,centroids)==1].shape
# Out:
# (0, 4, 21)

# %%
plt.plot(c.ideaDistribution[closest_centroids(c.allPositions, centroids)==0][10][0][:],'o')
plt.show()
